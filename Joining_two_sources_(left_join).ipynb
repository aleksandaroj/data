# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("countries.csv")

# %%
ds
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
dse = pd.read_csv("country_codes.csv")

# %%
dse
# Out:
#        country code
# 0  Afghanistan  AFG
# 1       Serbia  SRB

# %%
pd.merge(ds, dse, on="country")
# Out:
#         country  year  population code
# 0   Afghanistan  1952     8425333  AFG
# 1   Afghanistan  1957     9240934  AFG
# 2   Afghanistan  1962    10267083  AFG
# 3   Afghanistan  1967    11537966  AFG
# 4   Afghanistan  1972    13079460  AFG
# 5   Afghanistan  1977    14880372  AFG
# 6   Afghanistan  1982    12881816  AFG
# 7   Afghanistan  1987    13867957  AFG
# 8   Afghanistan  1992    16317921  AFG
# 9   Afghanistan  1997    22227415  AFG
# 10  Afghanistan  2002    25268405  AFG
# 11  Afghanistan  2007    31889923  AFG
# 12       Serbia  1952     6860147  SRB
# 13       Serbia  1957     7271135  SRB
# 14       Serbia  1962     7616060  SRB
# 15       Serbia  1967     7971222  SRB
# 16       Serbia  1972     8313288  SRB
# 17       Serbia  1977     8686367  SRB
# 18       Serbia  1982     9032824  SRB
# 19       Serbia  1987     9230783  SRB
# 20       Serbia  1992     9826397  SRB
# 21       Serbia  1997    10336594  SRB
# 22       Serbia  2002    10111559  SRB
# ...

# %%
ds.set_index("country", inplace=True)

# %%
dse.set_index("country", inplace=True)

# %%
ds
# Out:
#              year  population
# country
# Afghanistan  1952     8425333
# Afghanistan  1957     9240934
# Afghanistan  1962    10267083
# Afghanistan  1967    11537966
# Afghanistan  1972    13079460
# ...           ...         ...
# Zimbabwe     1987     9216418
# Zimbabwe     1992    10704340
# Zimbabwe     1997    11404948
# Zimbabwe     2002    11926563
# Zimbabwe     2007    12311143
#
# [1704 rows x 2 columns]

# %%
dse
# Out:
#             code
# country
# Afghanistan  AFG
# Serbia       SRB

# %%
joined = ds.join(dse)

# %%
joined
# Out:
#              year  population code
# country
# Afghanistan  1952     8425333  AFG
# Afghanistan  1957     9240934  AFG
# Afghanistan  1962    10267083  AFG
# Afghanistan  1967    11537966  AFG
# Afghanistan  1972    13079460  AFG
# ...           ...         ...  ...
# Zimbabwe     1987     9216418  NaN
# Zimbabwe     1992    10704340  NaN
# Zimbabwe     1997    11404948  NaN
# Zimbabwe     2002    11926563  NaN
# Zimbabwe     2007    12311143  NaN
#
# [1704 rows x 3 columns]

# %%
merged = pd.merge(ds, dse, on="country", how="left")

# %%
merged
# Out:
#              year  population code
# country
# Afghanistan  1952     8425333  AFG
# Afghanistan  1957     9240934  AFG
# Afghanistan  1962    10267083  AFG
# Afghanistan  1967    11537966  AFG
# Afghanistan  1972    13079460  AFG
# ...           ...         ...  ...
# Zimbabwe     1987     9216418  NaN
# Zimbabwe     1992    10704340  NaN
# Zimbabwe     1997    11404948  NaN
# Zimbabwe     2002    11926563  NaN
# Zimbabwe     2007    12311143  NaN
#
# [1704 rows x 3 columns]

# %%
afg = merged[merged.code == "AFG"]
afg
# Out:
#              year  population code
# country
# Afghanistan  1952     8425333  AFG
# Afghanistan  1957     9240934  AFG
# Afghanistan  1962    10267083  AFG
# Afghanistan  1967    11537966  AFG
# Afghanistan  1972    13079460  AFG
# Afghanistan  1977    14880372  AFG
# Afghanistan  1982    12881816  AFG
# Afghanistan  1987    13867957  AFG
# Afghanistan  1992    16317921  AFG
# Afghanistan  1997    22227415  AFG
# Afghanistan  2002    25268405  AFG
# Afghanistan  2007    31889923  AFG

# %%
srb = merged[merged.code == "SRB"]
srb
# Out:
#          year  population code
# country
# Serbia   1952     6860147  SRB
# Serbia   1957     7271135  SRB
# Serbia   1962     7616060  SRB
# Serbia   1967     7971222  SRB
# Serbia   1972     8313288  SRB
# Serbia   1977     8686367  SRB
# Serbia   1982     9032824  SRB
# Serbia   1987     9230783  SRB
# Serbia   1992     9826397  SRB
# Serbia   1997    10336594  SRB
# Serbia   2002    10111559  SRB
# Serbia   2007    10150265  SRB

# %%
plt.plot(afg.year, afg.population / 10 ** 6)
plt.plot(srb.year, srb.population / 10 ** 6)
plt.xlabel = "Godina"
plt.ylabel = "populacija (u milionima)"
plt.legend = (["Afganistan", "Srbija"])
plt.show()

# %%
## show distinct country names without codes

# %%
krs = merged[merged["code"].isnull()]

# %%
krs = krs["year"].unique()

# %%
krs
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007], dtype=int64)
